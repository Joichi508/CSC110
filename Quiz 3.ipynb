# %%
for x in ( x+1 for x in range(1000)):
    
    print(x,"We like Python's turtles!")
# Out:
# 1 We like Python's turtles!
# 2 We like Python's turtles!
# 3 We like Python's turtles!
# 4 We like Python's turtles!
# 5 We like Python's turtles!
# 6 We like Python's turtles!
# 7 We like Python's turtles!
# 8 We like Python's turtles!
# 9 We like Python's turtles!
# 10 We like Python's turtles!
# 11 We like Python's turtles!
# 12 We like Python's turtles!
# 13 We like Python's turtles!
# 14 We like Python's turtles!
# 15 We like Python's turtles!
# 16 We like Python's turtles!
# 17 We like Python's turtles!
# 18 We like Python's turtles!
# 19 We like Python's turtles!
# 20 We like Python's turtles!
# 21 We like Python's turtles!
# 22 We like Python's turtles!
# 23 We like Python's turtles!
# 24 We like Python's turtles!
# 25 We like Python's turtles!
# 26 We like Python's turtles!
# 27 We like Python's turtles!
# 28 We like Python's turtles!
# 29 We like Python's turtles!
# 30 We like Python's turtles!
# 31 We like Python's turtles!
# 32 We like Python's turtles!
# ...

# %%
xs = [12, 10, 32, 3, 66, 17, 42, 99, 20]

print("the numbers..")

for i in xs:
    print(i)

print("its square")

for i in xs:
    print(i, i ** 2)

print("the total..")

total = 0
for i in xs:
    total += i
print("Total:", total)

print("the product..")

product = 1
for i in xs:
    product *= i
print("Product", produc

# %%
import turtle
wn = turtle.Screen()
T = turtle.Turtle()

turns = [160, -43, 270, -97, -43, 200, -940, 17, -86]

for turn in turns:
    T.left(turn)
    T.forward(100)

wn.mainloop()
# Out:
# ---------------------------------------------------------------------------
# Terminator                                Traceback (most recent call last)
# <ipython-input-17-3cb60bea9df0> in <module>
#       1 import turtle
#       2 wn = turtle.Screen()
# ----> 3 T = turtle.Turtle()
#       4
#       5 turns = [160, -43, 270, -97, -43, 200, -940, 17, -86]
#
# ~/Applications/anaconda3/lib/python3.8/turtle.py in __init__(self, shape, undobuffersize, visible)
#    3812         if Turtle._screen is None:
#    3813             Turtle._screen = Screen()
# -> 3814         RawTurtle.__init__(self, Turtle._screen,
#    3815                            shape=shape,
#    3816                            undobuffersize=undobuffersize,
#
# ~/Applications/anaconda3/lib/python3.8/turtle.py in __init__(self, canvas, shape, undobuffersize, visible)
#    2556         self._undobuffersize = undobuffersize
#    2557         self.undobuffer = Tbuffer(undobuffersize)
# -> 2558         self._update()
# ...

# %%
import turtle
wn = turtle.Screen()
T = turtle.Turtle()

turns = [160, -43, 270, -97, -43, 200, -940, 17, -86]
heading = 0

for turn in turns:
    
    T.left(turn)
    heading = heading + 1
    T.forward(100)

wn.mainloop()

# %%
import turtle
wn = turtle.Screen()
T = turtle.Turtle()

T.speed(3)
T.pensize(3)

for x in range(5):
    T.forward(200)
    T.right(144)

T.hideturtle()

wn.mainloop
# Out:
# <bound method TurtleScreenBase.mainloop of <turtle._Screen object at 0x7fc8f0ddbb80>>

# %%
print("There is no collective noun for python. However, collective nouns for 'snake' can apply. No. Pythons are non-venomous.")
# Out:
# There is no collective noun for python. However, collective nouns for 'snake' can apply. No. Pythons are non-venomous.

# %%
for i in range (100):
    print("Hello")
# Out:
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
